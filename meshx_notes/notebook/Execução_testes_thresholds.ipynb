# %% [markdown]
# # Geração
#
# ## Pré-processamento
#
#
# Primeiramente, criamos o objeto dicionário com os seguintes parâmetros:
#
# - xmlMesh: parâmetro obrigatório em que será posto o caminho para o xml que deseja ser utilizado;
# - wordEmbedding: parâmetro obrigatório em que será posto o caminho para o Word Embedding que deseja ser utilizado;
# - Idioma: selecionar o idioma desejado, como "por" para português e "en" para inglês;
# - porcent_diagnosis: parâmetro opcional em que será posto o mínimo de similaridade que os termos – de qualifier diagnosis – devem ter com o original,  por padrão é iniciado com 9.0;
# - porcent_anatomy: parâmetro opcional em que será posto o mínimo de similaridade que os termos – de qualifier anatomy – devem ter com o original,  por padrão é iniciado com 9.0;
# - porcent_pharmacology: parâmetro opcional em que será posto o mínimo de similaridade que os termos – de qualifier pharmacology – devem ter com o original,  por padrão é iniciado com 9.3;
# - porcent_other: parâmetro opcional em que será posto o mínimo de similaridade que os termos – de qualifier other – devem ter com o original – por padrão é iniciado com 9.0;
# - \_topn: quantidade de termos o Word Embedding irá utilizar como termos similares;
# - printTime: parâmetro opcional em que se escolhe se deseja saber o tempo de execução das funções com verdadeiro ou falso, por padrão é iniciado com falso.

# %%
from Dicionarios import Dicionarios

Dicionario = Dicionarios(
        xmlMesh='pordesc2018.xml.gz', 
        wordEmbedding='health_w2v_unigram_50.bin',
        idioma = "por",
        porcent_methods = 0.89,
        porcent_diagnosis = 0.93,
        porcent_pharmacology=0.96,
        porcent_anatomy = 0.95,
        porcent_other=0.94, 
        _topn = 10,
        printTime = False,
        maisSimilar = True,
        similaridadeDefinicao = False
    
)
# Out:
# /opt/conda/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %% [markdown]
# # Execução
#
#
# Inicia-se com a função _run()_, caso tenha iniciado _printTime_ com True, então deverá utilizar quatro variáveis para que obtenha, respectivamente, o tempo de obtenção do qualifier, adicionar o termo no indice reverso, selecionar os termos no dicionario e adicionar os termos no dicionário.
#
# Após isso, com a função _salvaIndiceReverso()_ podemos salvar o indice reverso em um arquivo, o qual o caminho deste deve ser passado por parâmetro. A função _salvaDictMesh()_ salva o dicionário Mesh em um arquivo que também deve ser passado por parâmetro o seu caminho.

# %% [markdown]
# ## Criar o dicionário

# %%
#qualifier, add_indice, time_seleciona_TermosMesh, time_add_Mesh = Dicionario.run()
Dicionario.run()
Dicionario.salvaIndiceReverso('indiceReversoPT.dict.gz')
Dicionario.salvaDictMesh('dictMesh_.dict.gz')

#print(qualifier, add_indice, time_seleciona_TermosMesh, time_add_Mesh)

# %% [markdown]
# ## Criar tabela com os thresholds

# %%
import pandas as pd

dictPorcentagens = Dicionario.testaThresh()
Dicionario.salvaIndiceReverso('indiceReversoPT.dict.gz')
Dicionario.salvaDictMesh('dictMesh_.dict.gz')

df = pd.DataFrame(dictPorcentagens).T

df.to_csv('porcentagens_thresholds_MAIS_SIMILAR.csv.gz', compression='gzip')
#df.to_csv('porcentagens_thresholds_ULTIMO.csv.gz', compression='gzip')
#df.to_csv('porcentagens_thresholds_DESC.csv.gz', compression='gzip')

# %% [markdown]
# ## Salvar/Carregar o dicionário e o indice reverso

# %% [markdown]
# Com a função carrega_Dicionario() é possível utilizar um dicionário já armazenado previamente.
#
# A função carrega_IndiceReverso() é semelhante, mas nesta temos o armazenamento do Indice Reverso.

# %%
Dicionario.salvaIndiceReverso('indiceReversoPT.dict.gz')
Dicionario.salvaDictMesh('dictMesh_.dict.gz')

# %%
Dicionario.carrega_Dicionario('dictMesh_.dict.gz')
Dicionario.carrega_IndiceReverso('indiceReversoPT.dict.gz')
# Out:
# True

# %% [markdown]
# É possível visualizar as informações do Índice Rerverso com o comando abaixo:
#
# - Para acessar o Índice Reverso do termo somente é necessário pô-lo.
# - " \_i" ao fim dos termos que foram adicionados e que não estavam por padrão no dicionário.

# %%
Dicionario.indiceReverso
# Out:
# {'calcimicina': {'ID': 'D000001', 'similaridade': 1},
#  'calcimicina _i': {'ID': 'D000001', 'similaridade': 1},
#  'temefós': {'ID': 'D000002', 'similaridade': 1},
#  'temefos _i': {'ID': 'D000002', 'similaridade': 1},
#  'matadouros': {'ID': 'D000003', 'similaridade': 1},
#  'abatedouros': {'ID': 'D000003', 'similaridade': 1},
#  'matadouro': {'ID': 'D000003', 'similaridade': 1},
#  'matadouros _i': {'ID': 'D000003', 'similaridade': 1},
#  'abreviaturas como assunto': {'ID': 'D000004', 'similaridade': 1},
#  'acrônimos como assunto': {'ID': 'D000004', 'similaridade': 1},
#  'abreviatura dos medicamentos': {'ID': 'D000004', 'similaridade': 1},
#  'abreviaturas como assunto _i': {'ID': 'D000004', 'similaridade': 1},
#  'abdome': {'ID': 'D000005', 'similaridade': 1},
#  'abdômen': {'ID': 'D000005', 'similaridade': 1},
#  'abdome _i': {'ID': 'D000005', 'similaridade': 1},
#  'abdomen _i': {'ID': 'D000005', 'similaridade': 0.9887869358062744},
#  'abome _i': {'ID': 'D000005', 'similaridade': 0.9457325339317322},
#  'abd _i': {'ID': 'D000005', 'similaridade': 0.943260133266449},
#  'abdome agudo': {'ID': 'D000006', 'similaridade': 1},
#  'abdome agudo _i': {'ID': 'D000006', 'similaridade': 1},
#  'traumatismos abdominais': {'ID': 'D000007', 'similaridade': 1},
#  'lesões abdominais': {'ID': 'D000007', 'similaridade': 1},
#  'traumatismos abdominais _i': {'ID': 'D000007', 'similaridade': 1},
#  'neoplasias abdominais': {'ID': 'D000008', 'similaridade': 1},
#  'tumores abdominais': {'ID': 'D000008', 'similaridade': 1},
#  'tumores do abdome': {'ID': 'D000008', 'similaridade': 1},
#  'neoplasias abdominais _i': {'ID': 'D000008', 'similaridade': 1},
#  'músculos abdominais': {'ID': 'D000009', 'similaridade': 1},
#  'músculo cremaster': {'ID': 'D000009', 'similaridade': 1},
#  'músculo piramidal': {'ID': 'D000009', 'similaridade': 1},
#  'músculo quadrado do abdome': {'ID': 'D000009', 'similaridade': 1},
#  'músculo transverso abdominal': {'ID': 'D000009', 'similaridade': 1},
#  'músculo transverso do abdome': {'ID': 'D000009', 'similaridade': 1},
#  'musculos abdominais _i': {'ID': 'D000009', 'similaridade': 1},
#  'nervo abducente': {'ID': 'D000010', 'similaridade': 1},
#  'nervo craniano vi': {'ID': 'D000010', 'similaridade': 1},
#  'nervo motor ocular externo': {'ID': 'D000010', 'similaridade': 1},
#  'sexto nervo craniano': {'ID': 'D000010', 'similaridade': 1},
#  'vi nervo craniano': {'ID': 'D000010', 'similaridade': 1},
#  'vi par craniano': {'ID': 'D000010', 'similaridade': 1},
#  'nervo abducente _i': {'ID': 'D000010', 'similaridade': 1},
#  'vírus da leucemia murina de abelson': {'ID': 'D000011', 'similaridade': 1},
#  'vírus da leucemia de abelson': {'ID': 'D000011', 'similaridade': 1},
#  'virus da leucemia murina de abelson _i': {'ID': 'D000011',
#   'similaridade': 1},
#  'abetalipoproteinemia': {'ID': 'D000012', 'similaridade': 1},
#  'deficiência de proteína de transferência de triglicerídeo microssômico': {'ID': 'D000012',
#   'similaridade': 1},
#  'deficiência de proteína de transferência de triglicerídeos microssômicos': {'ID': 'D000012',
#   'similaridade': 1},
#  'doença por deficiência da proteína de transferência de triglicerídeos microssômicos': {'ID': 'D000012',
#   'similaridade': 1},
#  'síndrome de bassen-kornzweig': {'ID': 'D000012', 'similaridade': 1},
#  'abetalipoproteinemia _i': {'ID': 'D000012', 'similaridade': 1},
#  'anormalidades congênitas': {'ID': 'D000013', 'similaridade': 1},
#  'anomalia congênita': {'ID': 'D000013', 'similaridade': 1},
#  'anomalias congênitas': {'ID': 'D000013', 'similaridade': 1},
#  'anormalidade congênita': {'ID': 'D000013', 'similaridade': 1},
#  'defeitos congênitos': {'ID': 'D000013', 'similaridade': 1},
#  'deformidades': {'ID': 'D000013', 'similaridade': 1},
#  'malformações': {'ID': 'D000013', 'similaridade': 1},
#  'malformações congênitas': {'ID': 'D000013', 'similaridade': 1},
#  'anormalidades congenitas _i': {'ID': 'D000013', 'similaridade': 1},
#  'anormalidades induzidas por medicamentos': {'ID': 'D000014',
#   'similaridade': 1},
#  'anomalias induzidas por drogas': {'ID': 'D000014', 'similaridade': 1},
#  'anomalias induzidas por medicamentos': {'ID': 'D000014', 'similaridade': 1},
#  'anomalias induzidas por substâncias medicamentosas': {'ID': 'D000014',
#   'similaridade': 1},
#  'anormalidades induzidas por drogas': {'ID': 'D000014', 'similaridade': 1},
#  'anormalidades induzidas por substâncias medicamentosas': {'ID': 'D000014',
#   'similaridade': 1},
#  'malformações induzidas por drogas': {'ID': 'D000014', 'similaridade': 1},
#  'malformações induzidas por medicamentos': {'ID': 'D000014',
#   'similaridade': 1},
#  'malformações induzidas por substâncias medicamentosas': {'ID': 'D000014',
#   'similaridade': 1},
#  'anormalidades induzidas por medicamentos _i': {'ID': 'D000014',
#   'similaridade': 1},
#  'anormalidades múltiplas': {'ID': 'D000015', 'similaridade': 1},
#  'anomalias múltiplas': {'ID': 'D000015', 'similaridade': 1},
#  'malformações múltiplas': {'ID': 'D000015', 'similaridade': 1},
#  'anormalidades multiplas _i': {'ID': 'D000015', 'similaridade': 1},
#  'anormalidades induzidas por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'anomalia induzida por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'anomalias induzidas por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'anormalidade induzida por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'malformação induzida por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'malformações induzidas por radiação': {'ID': 'D000016', 'similaridade': 1},
#  'anormalidades induzidas por radiacao _i': {'ID': 'D000016',
#   'similaridade': 1},
#  'sistema do grupo sanguíneo abo': {'ID': 'D000017', 'similaridade': 1},
#  'grupo sanguíneo abh': {'ID': 'D000017', 'similaridade': 1},
#  'fatores abo': {'ID': 'D000017', 'similaridade': 1},
#  'sistema do grupo sanguineo abo _i': {'ID': 'D000017', 'similaridade': 1},
#  'abomaso': {'ID': 'D000018', 'similaridade': 1},
#  'abomaso _i': {'ID': 'D000018', 'similaridade': 1},
#  'abortivos': {'ID': 'D000019', 'similaridade': 1},
#  'efeito abortivo': {'ID': 'D000019', 'similaridade': 1},
#  'substâncias abortivas': {'ID': 'D000019', 'similaridade': 1},
#  'abortivos _i': {'ID': 'D000019', 'similaridade': 1},
#  'abortivos não esteroides': {'ID': 'D000020', 'similaridade': 1},
#  'abortivos nao esteroides _i': {'ID': 'D000020', 'similaridade': 1},
#  'abortivos esteroides': {'ID': 'D000021', 'similaridade': 1},
#  'abortivos esteroides _i': {'ID': 'D000021', 'similaridade': 1},
#  'aborto espontâneo': {'ID': 'D000022', 'similaridade': 1},
#  'aborto espontaneo _i': {'ID': 'D000022', 'similaridade': 1},
#  'aspirantes a aborto': {'ID': 'D000023', 'similaridade': 1},
#  'interessados em aborto': {'ID': 'D000023', 'similaridade': 1},
#  'requerentes de aborto': {'ID': 'D000023', 'similaridade': 1},
#  'aspirantes a aborto _i': {'ID': 'D000023', 'similaridade': 1},
#  'aborto criminoso': {'ID': 'D000024', 'similaridade': 1},
#  'aborto ilegal': {'ID': 'D000024', 'similaridade': 1},
#  'aborto criminoso _i': {'ID': 'D000024', 'similaridade': 1},
#  'aborto eugênico': {'ID': 'D000025', 'similaridade': 1},
#  'aborto eugenico _i': {'ID': 'D000025', 'similaridade': 1},
#  'aborto habitual': {'ID': 'D000026', 'similaridade': 1},
#  'abortamento habitual': {'ID': 'D000026', 'similaridade': 1},
#  'aborto recidivante': {'ID': 'D000026', 'similaridade': 1},
#  'perda recidivante do feto': {'ID': 'D000026', 'similaridade': 1},
#  'aborto habitual _i': {'ID': 'D000026', 'similaridade': 1},
#  'aborto incompleto': {'ID': 'D000027', 'similaridade': 1},
#  'aborto incompleto _i': {'ID': 'D000027', 'similaridade': 1},
#  'aborto induzido': {'ID': 'D000028', 'similaridade': 1},
#  'aborto provocado': {'ID': 'D000028', 'similaridade': 1},
#  'tasa de abortos': {'ID': 'D000028', 'similaridade': 1},
#  'tasa de aborto': {'ID': 'D000028', 'similaridade': 1},
#  'índice de aborto': {'ID': 'D000028', 'similaridade': 1},
#  'índice de abortos': {'ID': 'D000028', 'similaridade': 1},
#  'embriotomia': {'ID': 'D000028', 'similaridade': 1},
#  'aborto induzido _i': {'ID': 'D000028', 'similaridade': 1},
#  'aborto legal': {'ID': 'D000029', 'similaridade': 1},
#  'aborto sob demanda': {'ID': 'D000029', 'similaridade': 1},
#  'aborto por demanda': {'ID': 'D000029', 'similaridade': 1},
#  'aborto legal _i': {'ID': 'D000029', 'similaridade': 1},
#  'aborto retido': {'ID': 'D000030', 'similaridade': 1},
#  'aborto retido _i': {'ID': 'D000030', 'similaridade': 1},
#  'aborto séptico': {'ID': 'D000031', 'similaridade': 1},
#  'aborto septico _i': {'ID': 'D000031', 'similaridade': 1},
#  'aborto terapêutico': {'ID': 'D000032', 'similaridade': 1},
#  'aborto terapeutico _i': {'ID': 'D000032', 'similaridade': 1},
#  'ameaça de aborto': {'ID': 'D000033', 'similaridade': 1},
#  'ameaço de aborto': {'ID': 'D000033', 'similaridade': 1},
#  'ameaca de aborto _i': {'ID': 'D000033', 'similaridade': 1},
#  'aborto animal': {'ID': 'D000034', 'similaridade': 1},
#  'aborto animal _i': {'ID': 'D000034', 'similaridade': 1},
#  'ab-reação': {'ID': 'D000035', 'similaridade': 1},
#  'ab-reacao _i': {'ID': 'D000035', 'similaridade': 1},
#  'abrina': {'ID': 'D000036', 'similaridade': 1},
#  'abrina _i': {'ID': 'D000036', 'similaridade': 1},
#  'descolamento prematuro da placenta': {'ID': 'D000037', 'similaridade': 1},
#  'abruptio placentae': {'ID': 'D000037', 'similaridade': 1},
#  'descolamento prematuro da placenta _i': {'ID': 'D000037', 'similaridade': 1},
#  'abscesso': {'ID': 'D000038', 'similaridade': 1},
#  'abscesso _i': {'ID': 'D000038', 'similaridade': 1},
#  'abcesso _i': {'ID': 'D000038', 'similaridade': 0.9773133993148804},
#  'abscesso peritonsilar': {'ID': 'D000039', 'similaridade': 1},
#  'abscesso periamigdaliano': {'ID': 'D000039', 'similaridade': 1},
#  'abscesso peritonsilar _i': {'ID': 'D000039', 'similaridade': 1},
#  'ácido abscísico': {'ID': 'D000040', 'similaridade': 1},
#  'acido abscisico _i': {'ID': 'D000040', 'similaridade': 1},
#  'absenteísmo': {'ID': 'D000041', 'similaridade': 1},
#  'absentismo': {'ID': 'D000041', 'similaridade': 1},
#  'abstencionismo': {'ID': 'D000041', 'similaridade': 1},
#  'ausentismo': {'ID': 'D000041', 'similaridade': 1},
#  'ausência': {'ID': 'D000041', 'similaridade': 1},
#  'absenteismo _i': {'ID': 'D000041', 'similaridade': 1},
#  'absorção': {'ID': 'D000042', 'similaridade': 1},
#  'absorcao _i': {'ID': 'D000042', 'similaridade': 1},
#  'resumos e indexação como assunto': {'ID': 'D000043', 'similaridade': 1},
#  'indexação como assunto': {'ID': 'D000043', 'similaridade': 1},
#  'índices como assunto': {'ID': 'D000043', 'similaridade': 1},
#  'resumos como assunto': {'ID': 'D000043', 'similaridade': 1},
#  'resumos e indexacao como assunto _i': {'ID': 'D000043', 'similaridade': 1},
#  'dente suporte': {'ID': 'D000044', 'similaridade': 1},
#  'dente-suporte': {'ID': 'D000044', 'similaridade': 1},
#  'pivô': {'ID': 'D000044', 'similaridade': 1},
#  'dente suporte _i': {'ID': 'D000044', 'similaridade': 1},
#  'acacia': {'ID': 'D000045', 'similaridade': 1},
#  'acacia arabica': {'ID': 'D000045', 'similaridade': 1},
#  'acacia decurrens': {'ID': 'D000045', 'similaridade': 1},
#  'acacia mearnsii': {'ID': 'D000045', 'similaridade': 1},
#  'acácia da austrália': {'ID': 'D000045', 'similaridade': 1},
#  'acácia-negra': {'ID': 'D000045', 'similaridade': 1},
#  'acácia-do-nilo': {'ID': 'D000045', 'similaridade': 1},
#  'árvore-da-goma-arábica': {'ID': 'D000045', 'similaridade': 1},
#  'acacia _i': {'ID': 'D000045', 'similaridade': 1},
#  'centros médicos acadêmicos': {'ID': 'D000046', 'similaridade': 1},
#  'centros médicos universitários': {'ID': 'D000046', 'similaridade': 1},
#  'centros medicos academicos _i': {'ID': 'D000046', 'similaridade': 1},
#  'academias e institutos': {'ID': 'D000047', 'similaridade': 1},
#  'institutos': {'ID': 'D000047', 'similaridade': 1},
#  'institutos de pesquisa': {'ID': 'D000047', 'similaridade': 1},
#  'centro de pesquisa': {'ID': 'D000047', 'similaridade': 1},
#  'instituição de pesquisa': {'ID': 'D000047', 'similaridade': 1},
#  'academias e institutos _i': {'ID': 'D000047', 'similaridade': 1},
#  'acanthamoeba': {'ID': 'D000048', 'similaridade': 1},
#  'acanthamoeba _i': {'ID': 'D000048', 'similaridade': 1},
#  'acantocéfalos': {'ID': 'D000049', 'similaridade': 1},
#  'acanthocephala': {'ID': 'D000049', 'similaridade': 1},
#  'vermes de cabeça espinhosa': {'ID': 'D000049', 'similaridade': 1},
#  'acantocefalos _i': {'ID': 'D000049', 'similaridade': 1},
#  'acantócitos': {'ID': 'D000050', 'similaridade': 1},
#  'acantocitos _i': {'ID': 'D000050', 'similaridade': 1},
#  'acantólise': {'ID': 'D000051', 'similaridade': 1},
#  'acantolise _i': {'ID': 'D000051', 'similaridade': 1},
#  'acantose nigricans': {'ID': 'D000052', 'similaridade': 1},
#  'acantose nigricans _i': {'ID': 'D000052', 'similaridade': 1},
#  'ácaros e carrapatos': {'ID': 'D000053', 'similaridade': 1},
#  'acari': {'ID': 'D000053', 'similaridade': 1},
#  'acarina': {'ID': 'D000053', 'similaridade': 1},
#  'acarinos': {'ID': 'D000053', 'similaridade': 1},
#  'acaros e carrapatos _i': {'ID': 'D000053', 'similaridade': 1},
#  'aceleração': {'ID': 'D000054', 'similaridade': 1},
#  'aceleracao _i': {'ID': 'D000054', 'similaridade': 1},
#  'nervo acessório': {'ID': 'D000055', 'similaridade': 1},
#  'décimo primeiro nervo craniano': {'ID': 'D000055', 'similaridade': 1},
#  'nervo acessório espinal': {'ID': 'D000055', 'similaridade': 1},
#  'nervo acessório espinhal': {'ID': 'D000055', 'similaridade': 1},
#  'nervo craniano xi': {'ID': 'D000055', 'similaridade': 1},
#  'xi nervo craniano': {'ID': 'D000055', 'similaridade': 1},
#  'xi par craniano': {'ID': 'D000055', 'similaridade': 1},
#  'nervo acessorio _i': {'ID': 'D000055', 'similaridade': 1},
#  'prevenção de acidentes': {'ID': 'D000056', 'similaridade': 1},
#  'prevencao de acidentes _i': {'ID': 'D000056', 'similaridade': 1},
#  'propensão a acidentes': {'ID': 'D000057', 'similaridade': 1},
#  'propensao a acidentes _i': {'ID': 'D000057', 'similaridade': 1},
#  'acidentes por quedas': {'ID': 'D000058', 'similaridade': 1},
#  'acidentes por quedas _i': {'ID': 'D000058', 'similaridade': 1},
#  'acidentes': {'ID': 'D000059', 'similaridade': 1},
#  'acidentes _i': {'ID': 'D000059', 'similaridade': 1},
#  'acidentes aeronáuticos': {'ID': 'D000060', 'similaridade': 1},
#  'acidentes aeronauticos _i': {'ID': 'D000060', 'similaridade': 1},
#  'acidentes domésticos': {'ID': 'D000061', 'similaridade': 1},
#  'acidentes domesticos _i': {'ID': 'D000061', 'similaridade': 1},
#  'acidentes de trabalho': {'ID': 'D000062', 'similaridade': 1},
#  'acidente de trabalho': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes ocupacionais': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes de trabalho fatais': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes de trabalho graves': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes na indústria': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes de trabalho _i': {'ID': 'D000062', 'similaridade': 1},
#  'acidentes de trânsito': {'ID': 'D000063', 'similaridade': 1},
#  'acidente de tráfego': {'ID': 'D000063', 'similaridade': 1},
#  'acidente de trânsito': {'ID': 'D000063', 'similaridade': 1},
#  'acidentes de transporte': {'ID': 'D000063', 'similaridade': 1},
#  'acidentes de tráfego': {'ID': 'D000063', 'similaridade': 1},
#  'acidentes de transito _i': {'ID': 'D000063', 'similaridade': 1},
#  'aclimatação': {'ID': 'D000064', 'similaridade': 1},
#  'aclimação': {'ID': 'D000064', 'similaridade': 1},
#  'aclimatacao _i': {'ID': 'D000064', 'similaridade': 1},
#  'acomodação ocular': {'ID': 'D000065', 'similaridade': 1},
#  'acomodacao ocular _i': {'ID': 'D000065', 'similaridade': 1},
#  'contabilidade': {'ID': 'D000066', 'similaridade': 1},
#  'contabilidade de custos': {'ID': 'D000066', 'similaridade': 1},
#  'contabilidade _i': {'ID': 'D000066', 'similaridade': 1},
#  'telemarketing _i': {'ID': 'D000066', 'similaridade': 0.9176017642021179},
#  'balconista _i': {'ID': 'D000329', 'similaridade': 0.9413712620735168},
#  'obras _i': {'ID': 'D059027', 'similaridade': 0.9194687008857727},
#  'vendas _i': {'ID': 'D000329', 'similaridade': 0.9292215704917908},
#  'escritorio _i': {'ID': 'D000066', 'similaridade': 0.9050952196121216},
#  'servente _i': {'ID': 'D000067565', 'similaridade': 0.9148172736167908},
#  'idosos _i': {'ID': 'D000066', 'similaridade': 0.8948976993560791},
#  'vendedora _i': {'ID': 'D000067565', 'similaridade': 0.9234588742256165},
#  'zelador _i': {'ID': 'D000329', 'similaridade': 0.9293844103813171},
#  'indústria de petróleo e gás': {'ID': 'D000066388', 'similaridade': 1},
#  'indústria petroquímica': {'ID': 'D000066388', 'similaridade': 1},
#  'indústria petroleira': {'ID': 'D000066388', 'similaridade': 1},
#  'indústria petrolífera': {'ID': 'D000066388', 'similaridade': 1},
#  'indústria do petróleo': {'ID': 'D000066388', 'similaridade': 1},
#  'refinarias de petróleo': {'ID': 'D000066388', 'similaridade': 1},
#  'derivados de petróleo': {'ID': 'D000066388', 'similaridade': 1},
#  'industria de petroleo e gas _i': {'ID': 'D000066388', 'similaridade': 1},
#  'indústria do carvão mineral': {'ID': 'D000066428', 'similaridade': 1},
#  'indústria da mineração do carvão': {'ID': 'D000066428', 'similaridade': 1},
#  'industria do carvao mineral _i': {'ID': 'D000066428', 'similaridade': 1},
#  'dirigir sob a influência': {'ID': 'D000066448', 'similaridade': 1},
#  'dirigir sob influência': {'ID': 'D000066448', 'similaridade': 1},
#  'dirigir sob a influencia _i': {'ID': 'D000066448', 'similaridade': 1},
#  'células-tronco embrionárias humanas': {'ID': 'D000066449',
#   'similaridade': 1},
#  'células estaminais embrionárias humanas': {'ID': 'D000066449',
#   'similaridade': 1},
#  'células tronco embrionárias humanas': {'ID': 'D000066449',
#   'similaridade': 1},
#  'células tronco humanas embrionárias': {'ID': 'D000066449',
#   'similaridade': 1},
#  'células-tronco humanas embrionárias': {'ID': 'D000066449',
#   'similaridade': 1},
#  'celulas-tronco embrionarias humanas _i': {'ID': 'D000066449',
#   'similaridade': 1},
#  'células-tronco embrionárias murinas': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células estaminais embrionárias murinas': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células estaminais embrionárias de camundongos': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células tronco embrionárias murinas': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células tronco embrionárias de camundongos': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células-tronco embrionárias de camundongos': {'ID': 'D000066450',
#   'similaridade': 1},
#  'celulas-tronco embrionarias murinas _i': {'ID': 'D000066450',
#   'similaridade': 1},
#  'células germinativas embrionárias': {'ID': 'D000066473', 'similaridade': 1},
#  'célula germinativa embrionária': {'ID': 'D000066473', 'similaridade': 1},
#  'células embrionárias germinativas': {'ID': 'D000066473', 'similaridade': 1},
#  'células germinativas de embriões': {'ID': 'D000066473', 'similaridade': 1},
#  'células germinativas do embrião': {'ID': 'D000066473', 'similaridade': 1},
#  'células germinativas dos embriões': {'ID': 'D000066473', 'similaridade': 1},
#  'celulas germinativas embrionarias _i': {'ID': 'D000066473',
#   'similaridade': 1},
#  'desempenho profissional': {'ID': 'D000066477', 'similaridade': 1},
#  'desempenho laboral': {'ID': 'D000066477', 'similaridade': 1},
#  'desempenho ocupacional': {'ID': 'D000066477', 'similaridade': 1},
#  'desempenho no trabalho': {'ID': 'D000066477', 'similaridade': 1},
#  'desempenho profissional _i': {'ID': 'D000066477', 'similaridade': 1},
#  'comportamento criminoso': {'ID': 'D000066479', 'similaridade': 1},
#  'comportamento criminoso _i': {'ID': 'D000066479', 'similaridade': 1},
#  'tomada de decisão clínica': {'ID': 'D000066491', 'similaridade': 1},
#  'tomada de decisões clínicas': {'ID': 'D000066491', 'similaridade': 1},
#  'tomadas de decisão clínica': {'ID': 'D000066491', 'similaridade': 1},
#  'tomada de decisao clinica _i': {'ID': 'D000066491', 'similaridade': 1},
#  'envelhecimento cognitivo': {'ID': 'D000066492', 'similaridade': 1},
#  'envelhecimento cognitivo _i': {'ID': 'D000066492', 'similaridade': 1},
#  'neurociência cognitiva': {'ID': 'D000066494', 'similaridade': 1},
#  'neurociencia cognitiva _i': {'ID': 'D000066494', 'similaridade': 1},
#  'ajustamento emocional': {'ID': 'D000066498', 'similaridade': 1},
#  'ajustamento psicológico': {'ID': 'D000066498', 'similaridade': 1},
#  'ajuste emocional': {'ID': 'D000066498', 'similaridade': 1},
#  'ajustamento emocional _i': {'ID': 'D000066498', 'similaridade': 1},
#  'reconhecimento facial': {'ID': 'D000066499', 'similaridade': 1},
#  'reconhecimento facial _i': {'ID': 'D000066499', 'similaridade': 1},
#  'avós': {'ID': 'D000066502', 'similaridade': 1},
#  'avó': {'ID': 'D000066502', 'similaridade': 1},
#  'avô': {'ID': 'D000066502', 'similaridade': 1},
#  'avos _i': {'ID': 'D000066502', 'similaridade': 1},
#  'comportamento de busca de ajuda': {'ID': 'D000066505', 'similaridade': 1},
#  'comportamento de busca de ajuda _i': {'ID': 'D000066505', 'similaridade': 1},
#  'heurística': {'ID': 'D000066506', 'similaridade': 1},
#  'heuristica _i': {'ID': 'D000066506', 'similaridade': 1},
#  'violência por parceiro íntimo': {'ID': 'D000066511', 'similaridade': 1},
#  'violência contra parceiro íntimo': {'ID': 'D000066511', 'similaridade': 1},
#  'violência contra a parceira íntima': {'ID': 'D000066511', 'similaridade': 1},
#  'violência entre parceiros íntimos': {'ID': 'D000066511', 'similaridade': 1},
#  'violencia por parceiro intimo _i': {'ID': 'D000066511', 'similaridade': 1},
#  'reabilitação neurológica': {'ID': 'D000066530', 'similaridade': 1},
#  'reabilitacao neurologica _i': {'ID': 'D000066530', 'similaridade': 1},
#  'abuso físico': {'ID': 'D000066550', 'similaridade': 1},
#  'abuso fisico _i': {'ID': 'D000066550', 'similaridade': 1},
#  'comportamento problema': {'ID': 'D000066553', 'similaridade': 1},
#  'comportamento problemático': {'ID': 'D000066553', 'similaridade': 1},
#  'comportamento-problema': {'ID': 'D000066553', 'similaridade': 1},
#  'psicologia do comportamento disfuncional': {'ID': 'D000066553',
#   'similaridade': 1},
#  'comportamento disruptivo': {'ID': 'D000066553', 'similaridade': 1},
#  'comportamento problema _i': {'ID': 'D000066553', 'similaridade': 1},
#  'consumo de álcool por menores': {'ID': 'D000066608', 'similaridade': 1},
#  'consumo alcoólico por menores': {'ID': 'D000066608', 'similaridade': 1},
#  'consumo alcoólico por menores de idade': {'ID': 'D000066608',
#   'similaridade': 1},
#  'consumo de álcool por menores de idade': {'ID': 'D000066608',
#   'similaridade': 1},
#  'consumo de alcool por menores _i': {'ID': 'D000066608', 'similaridade': 1},
#  'expressão ectópica do gene': {'ID': 'D000066630', 'similaridade': 1},
#  'expressão gênica ectópica': {'ID': 'D000066630', 'similaridade': 1},
#  'expressao ectopica do gene _i': {'ID': 'D000066630', 'similaridade': 1},
#  'plasticidade celular': {'ID': 'D000066670', 'similaridade': 1},
#  'plasticidade celular _i': {'ID': 'D000066670', 'similaridade': 1},
#  'autorrenovação celular': {'ID': 'D000066673', 'similaridade': 1},
#  'auto-renovação das células': {'ID': 'D000066673', 'similaridade': 1},
#  'auto-renovação de células': {'ID': 'D000066673', 'similaridade': 1},
#  'autorrenovação das células': {'ID': 'D000066673', 'similaridade': 1},
#  'autorrenovação de células': {'ID': 'D000066673', 'similaridade': 1},
#  'autorrenovação da célula-tronco': {'ID': 'D000066673', 'similaridade': 1},
#  'autorrenovação de células-tronco': {'ID': 'D000066673', 'similaridade': 1},
#  'autorrenovacao celular _i': {'ID': 'D000066673', 'similaridade': 1},
#  'pesquisa de reabilitação': {'ID': 'D000066768', 'similaridade': 1},
#  'pesquisa de reabilitacao _i': {'ID': 'D000066768', 'similaridade': 1},
#  'ortodontistas': {'ID': 'D000066792', 'similaridade': 1},
#  'ortodontista': {'ID': 'D000066792', 'similaridade': 1},
#  'ortodontistas _i': {'ID': 'D000066792', 'similaridade': 1},
#  'cirurgiões bucomaxilofaciais': {'ID': 'D000066794', 'similaridade': 1},
#  'cirurgiões bucais e maxilofaciais': {'ID': 'D000066794', 'similaridade': 1},
#  'cirurgiões buco-maxilo-faciais': {'ID': 'D000066794', 'similaridade': 1},
#  'cirurgiões orais e maxilofaciais': {'ID': 'D000066794', 'similaridade': 1},
#  'cirurgiões da boca, maxilares e da face': {'ID': 'D000066794',
#   'similaridade': 1},
#  'cirurgioes bucomaxilofaciais _i': {'ID': 'D000066794', 'similaridade': 1},
#  'neuroproteção': {'ID': 'D000066829', 'similaridade': 1},
#  'neuroprotecao _i': {'ID': 'D000066829', 'similaridade': 1},
#  'alimentos, dieta e nutrição': {'ID': 'D000066888', 'similaridade': 1},
#  'alimento, dieta e nutrição': {'ID': 'D000066888', 'similaridade': 1},
#  'alimentos, alimentação e nutrição': {'ID': 'D000066888', 'similaridade': 1},
#  'alimentos, regimes alimentares e nutrição': {'ID': 'D000066888',
#   'similaridade': 1},
#  'dieta, alimento e nutrição': {'ID': 'D000066888', 'similaridade': 1},
#  'dieta, alimentos e nutrição': {'ID': 'D000066888', 'similaridade': 1},
#  'nutrição, dieta e alimentação': {'ID': 'D000066888', 'similaridade': 1},
#  'nutrição, dieta e alimento': {'ID': 'D000066888', 'similaridade': 1},
#  'nutrição, dieta e alimentos': {'ID': 'D000066888', 'similaridade': 1},
#  'nutrição, regime alimentar e alimentos': {'ID': 'D000066888',
#   'similaridade': 1},
#  'alimentos, dieta e nutricao _i': {'ID': 'D000066888', 'similaridade': 1},
#  'triticale': {'ID': 'D000066889', 'similaridade': 1},
#  'triticale _i': {'ID': 'D000066889', 'similaridade': 1},
#  'resultados de cuidados críticos': {'ID': 'D000066891', 'similaridade': 1},
#  'evolução do cuidado crítico': {'ID': 'D000066891', 'similaridade': 1},
#  'evolução dos cuidados críticos': {'ID': 'D000066891', 'similaridade': 1},
#  'resultado do cuidado crítico': {'ID': 'D000066891', 'similaridade': 1},
#  'resultados da terapia intensiva': {'ID': 'D000066891', 'similaridade': 1},
#  'resultados de terapia intensiva': {'ID': 'D000066891', 'similaridade': 1},
#  'resultados dos cuidados críticos': {'ID': 'D000066891', 'similaridade': 1},
#  'resultados de cuidados criticos _i': {'ID': 'D000066891', 'similaridade': 1},
#  'treinamento por simulação': {'ID': 'D000066908', 'similaridade': 1},
#  'treinamento simulado': {'ID': 'D000066908', 'similaridade': 1},
#  'treinamento por simulacao _i': {'ID': 'D000066908', 'similaridade': 1},
#  'milhetes': {'ID': 'D000066928', 'similaridade': 1},
#  'milhete': {'ID': 'D000066928', 'similaridade': 1},
#  'milheto': {'ID': 'D000066928', 'similaridade': 1},
#  'milhetos': {'ID': 'D000066928', 'similaridade': 1},
#  'milho-miúdo': {'ID': 'D000066928', 'similaridade': 1},
#  'painço': {'ID': 'D000066928', 'similaridade': 1},
#  'painços': {'ID': 'D000066928', 'similaridade': 1},
#  'milhetes _i': {'ID': 'D000066928', 'similaridade': 1},
#  'ciências biocomportamentais': {'ID': 'D000066949', 'similaridade': 1},
#  'ciencias biocomportamentais _i': {'ID': 'D000066949', 'similaridade': 1},
#  'coroa de proteína': {'ID': 'D000066970', 'similaridade': 1},
#  'coroa proteica': {'ID': 'D000066970', 'similaridade': 1},
#  'corona proteica': {'ID': 'D000066970', 'similaridade': 1},
#  'corona de proteína': {'ID': 'D000066970', 'similaridade': 1},
#  'coroa de proteina _i': {'ID': 'D000066970', 'similaridade': 1},
#  'vegetarianos': {'ID': 'D000066988', 'similaridade': 1},
#  'vegetarianos _i': {'ID': 'D000066988', 'similaridade': 1},
#  'veganos': {'ID': 'D000066989', 'similaridade': 1},
#  'veganos _i': {'ID': 'D000066989', 'similaridade': 1},
#  'contas a pagar e a receber': {'ID': 'D000067', 'similaridade': 1},
#  'contas a pagar e a receber _i': {'ID': 'D000067', 'similaridade': 1},
#  'esportes juvenis': {'ID': 'D000067009', 'similaridade': 1},
#  'esportes para jovens': {'ID': 'D000067009', 'similaridade': 1},
#  'esportes juvenis _i': {'ID': 'D000067009', 'similaridade': 1},
#  'alfabetização': {'ID': 'D000067010', 'similaridade': 1},
#  'alfabetismo': {'ID': 'D000067010', 'similaridade': 1},
#  'analfabetismo': {'ID': 'D000067010', 'similaridade': 1},
#  'alfabetizacao _i': {'ID': 'D000067010', 'similaridade': 1},
#  'desnutrição aguda grave': {'ID': 'D000067011', 'similaridade': 1},
#  'desnutricao aguda grave _i': {'ID': 'D000067011', 'similaridade': 1},
#  'conta bancária': {'ID': 'D000067012', 'similaridade': 1},
#  'conta corrente comercial': {'ID': 'D000067012', 'similaridade': 1},
#  'conta corrente individual': {'ID': 'D000067012', 'similaridade': 1},
#  'serviços bancários pessoais': {'ID': 'D000067012', 'similaridade': 1},
#  'conta de poupança': {'ID': 'D000067012', 'similaridade': 1},
#  'caderneta de poupança': {'ID': 'D000067012', 'similaridade': 1},
#  'conta poupança': {'ID': 'D000067012', 'similaridade': 1},
#  'conta corrente': {'ID': 'D000067012', 'similaridade': 1},
#  'conta bancaria _i': {'ID': 'D000067012', 'similaridade': 1},
#  'projeto arquitetônico baseado em evidências': {'ID': 'D000067013',
#   'similaridade': 1},
#  'arquitetura hospitalar baseada em evidências': {'ID': 'D000067013',
#   'similaridade': 1},
#  'design arquitetônico baseado em evidências': {'ID': 'D000067013',
#   'similaridade': 1},
#  'design baseado em evidências': {'ID': 'D000067013', 'similaridade': 1},
#  'projeto de instalação baseado em evidências': {'ID': 'D000067013',
#   'similaridade': 1},
#  'projeto arquitetonico baseado em evidencias _i': {'ID': 'D000067013',
#   'similaridade': 1},
#  'aparência física': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência corporal': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência corporal física': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência física corporal': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência física do corpo': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência do corpo': {'ID': 'D000067029', 'similaridade': 1},
#  'aparência do corpo físico': {'ID': 'D000067029', 'similaridade': 1},
#  'aparencia fisica _i': {'ID': 'D000067029', 'similaridade': 1},
#  'sucos de frutas e vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de fruta e hortaliça': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de fruta e legume': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de fruta e vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de fruta e verdura': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de frutas e hortaliças': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de frutas e legumes': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de frutas e vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de frutas e verduras': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de frutas e hortaliças': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de frutas e legumes': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de frutas e verduras': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de hortaliça': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de legume': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de planta': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de verdura': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de hortaliças': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de legumes': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de plantas': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de verduras': {'ID': 'D000067030', 'similaridade': 1},
#  'suco vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de hortaliça': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de hortaliças': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de legume': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de legumes': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de planta': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de verdura': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de verduras': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de hortaliças': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de verduras': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de legume': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de planta': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de vegetal': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de verdura': {'ID': 'D000067030', 'similaridade': 1},
#  'sumos vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'sumos de legumes': {'ID': 'D000067030', 'similaridade': 1},
#  'sumos de plantas': {'ID': 'D000067030', 'similaridade': 1},
#  'sumos de vegetais': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de fruta': {'ID': 'D000067030', 'similaridade': 1},
#  'bebida de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'bebidas de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de fruta': {'ID': 'D000067030', 'similaridade': 1},
#  'suco de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de fruta': {'ID': 'D000067030', 'similaridade': 1},
#  'sumo de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'sumos de frutas': {'ID': 'D000067030', 'similaridade': 1},
#  'sucos de frutas e vegetais _i': {'ID': 'D000067030', 'similaridade': 1},
#  'ghee': {'ID': 'D000067048', 'similaridade': 1},
#  'ghi': {'ID': 'D000067048', 'similaridade': 1},
#  'ghee _i': {'ID': 'D000067048', 'similaridade': 1},
#  'fraturamento hidráulico': {'ID': 'D000067071', 'similaridade': 1},
#  'fraturamento hidraulico _i': {'ID': 'D000067071', 'similaridade': 1},
#  'trauma psicológico': {'ID': 'D000067073', 'similaridade': 1},
#  'trauma psicologico _i': {'ID': 'D000067073', 'similaridade': 1},
#  'infuência dos pares': {'ID': 'D000067074', 'similaridade': 1},
#  'influência do grupo': {'ID': 'D000067074', 'similaridade': 1},
#  'influência dos colegas': {'ID': 'D000067074', 'similaridade': 1},
#  'influência dos companheiros': {'ID': 'D000067074', 'similaridade': 1},
#  'infuencia dos pares _i': {'ID': 'D000067074', 'similaridade': 1},
#  'produtos vegetais': {'ID': 'D000067075', 'similaridade': 1},
#  'produtos vegetais _i': {'ID': 'D000067075', 'similaridade': 1},
#  'publicidade direta ao consumidor': {'ID': 'D000067088', 'similaridade': 1},
#  'propaganda direta ao consumidor': {'ID': 'D000067088', 'similaridade': 1},
#  'publicidade direta ao consumidor _i': {'ID': 'D000067088',
#   'similaridade': 1},
#  'triagem e testes direto ao consumidor': {'ID': 'D000067108',
#   'similaridade': 1},
#  'triagem e teste diagnóstico direto ao consumidor': {'ID': 'D000067108',
#   'similaridade': 1},
#  'triagem e teste direto ao consumidor': {'ID': 'D000067108',
#   'similaridade': 1},
#  'triagem e testes diagnósticos direto ao consumidor': {'ID': 'D000067108',
#   'similaridade': 1},
#  'triagem e testes direto ao consumidor _i': {'ID': 'D000067108',
#   'similaridade': 1},
#  'vesículas extracelulares': {'ID': 'D000067128', 'similaridade': 1},
#  'vesiculas extracelulares _i': {'ID': 'D000067128', 'similaridade': 1},
#  'micovírus': {'ID': 'D000067148', 'similaridade': 1},
#  'vírus fúngicos': {'ID': 'D000067148', 'similaridade': 1},
#  'vírus de fungos': {'ID': 'D000067148', 'similaridade': 1},
#  'micovirus _i': {'ID': 'D000067148', 'similaridade': 1},
#  'telócitos': {'ID': 'D000067170', 'similaridade': 1},
#  'telocitos _i': {'ID': 'D000067170', 'similaridade': 1},
#  'exoesqueleto energizado': {'ID': 'D000067190', 'similaridade': 1},
#  'armadura elétrica': {'ID': 'D000067190', 'similaridade': 1},
#  'dispositivo exoesqueleto': {'ID': 'D000067190', 'similaridade': 1},
#  'dispositivo de exoesqueleto': {'ID': 'D000067190', 'similaridade': 1},
#  'exoterno': {'ID': 'D000067190', 'similaridade': 1},
#  'exoesqueleto robótico': {'ID': 'D000067190', 'similaridade': 1},
#  'dispositivo robótico exoesqueleto': {'ID': 'D000067190', 'similaridade': 1},
#  'exoesqueleto energizado _i': {'ID': 'D000067190', 'similaridade': 1},
#  'hipersensibilidade a frutos do mar': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a camarão': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a camarões': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a crustáceos e moluscos': {'ID': 'D000067208',
#   'similaridade': 1},
#  'hipersensibilidade a mariscos': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a mexilhões': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a moluscos': {'ID': 'D000067208', 'similaridade': 1},
#  'hipersensibilidade a moluscos e crustáceos': {'ID': 'D000067208',
#   'similaridade': 1},
#  'hipersensibilidade a frutos do mar _i': {'ID': 'D000067208',
#   'similaridade': 1},
#  'falha da terapia de resgate': {'ID': 'D000067248', 'similaridade': 1},
#  'falha do resgate terapêutico': {'ID': 'D000067248', 'similaridade': 1},
#  'falha do tratamento de resgate': {'ID': 'D000067248', 'similaridade': 1},
#  'falha no resgate em cuidados de saúde': {'ID': 'D000067248',
#   'similaridade': 1},
#  'incapacidade de inversão do quadro pelo cuidado de saúde': {'ID': 'D000067248',
#   'similaridade': 1},
#  'incapacidade de recuperação pelo cuidado de saúde': {'ID': 'D000067248',
#   'similaridade': 1},
#  'incapacidade de reversão do quadro pelo cuidado de saúde': {'ID': 'D000067248',
#   'similaridade': 1},
#  'falha da terapia de resgate _i': {'ID': 'D000067248', 'similaridade': 1},
#  'reabilitação psiquiátrica': {'ID': 'D000067250', 'similaridade': 1},
#  'reabilitacao psiquiatrica _i': {'ID': 'D000067250', 'similaridade': 1},
#  'exacerbação dos sintomas': {'ID': 'D000067251', 'similaridade': 1},
#  'exacerbação súbita dos sintomas': {'ID': 'D000067251', 'similaridade': 1},
#  'exacerbação transitória dos sintomas': {'ID': 'D000067251',
#   'similaridade': 1},
#  'flare up de sintomas': {'ID': 'D000067251', 'similaridade': 1},
#  'surgimento de sintomas': {'ID': 'D000067251', 'similaridade': 1},
#  'exacerbacao dos sintomas _i': {'ID': 'D000067251', 'similaridade': 1},
#  'preparação de coração isolado': {'ID': 'D000067268', 'similaridade': 1},
#  'preparação do coração isolado': {'ID': 'D000067268', 'similaridade': 1},
#  'preparacao de coracao isolado _i': {'ID': 'D000067268', 'similaridade': 1},
#  'dieta vegana': {'ID': 'D000067269', 'similaridade': 1},
#  'dieta vegan': {'ID': 'D000067269', 'similaridade': 1},
#  'dieta vegã': {'ID': 'D000067269', 'similaridade': 1},
#  'dieta végan': {'ID': 'D000067269', 'similaridade': 1},
#  'dieta vegana _i': {'ID': 'D000067269', 'similaridade': 1},
#  'técnicas de observação do comportamento': {'ID': 'D000067289',
#   'similaridade': 1},
#  'técnicas de observação comportamental': {'ID': 'D000067289',
#   'similaridade': 1},
#  'tecnicas de observacao do comportamento _i': {'ID': 'D000067289',
#   'similaridade': 1},
#  'escala de avaliação comportamental': {'ID': 'D000067290', 'similaridade': 1},
#  'escala de avaliação de comportamentos': {'ID': 'D000067290',
#   'similaridade': 1},
#  'escala de classificação comportamental': {'ID': 'D000067290',
#   'similaridade': 1},
#  'escala de classificação do comportamento': {'ID': 'D000067290',
#   'similaridade': 1},
#  'escala de graus de comportamento': {'ID': 'D000067290', 'similaridade': 1},
#  'escala de avaliacao comportamental _i': {'ID': 'D000067290',
#   'similaridade': 1},
#  'consumo de álcool na faculdade': {'ID': 'D000067292', 'similaridade': 1},
#  'alcoolismo na faculdade': {'ID': 'D000067292', 'similaridade': 1},
#  'alcoolismo na universidade': {'ID': 'D000067292', 'similaridade': 1},
#  'consumo de álcool em escolas': {'ID': 'D000067292', 'similaridade': 1},
#  'consumo de álcool em faculdades': {'ID': 'D000067292', 'similaridade': 1},
#  'consumo de álcool em universidades': {'ID': 'D000067292', 'similaridade': 1},
#  'consumo de álcool na universidade': {'ID': 'D000067292', 'similaridade': 1},
#  'consumo de alcool na faculdade _i': {'ID': 'D000067292', 'similaridade': 1},
#  'obesidade metabolicamente benigna': {'ID': 'D000067329', 'similaridade': 1},
#  'obesidade metabolicamente benigna _i': {'ID': 'D000067329',
#   'similaridade': 1},
#  'grãos integrais': {'ID': 'D000067348', 'similaridade': 1},
#  'cariopse integral': {'ID': 'D000067348', 'similaridade': 1},
#  'cariopses integrais': {'ID': 'D000067348', 'similaridade': 1},
#  'grão integral': {'ID': 'D000067348', 'similaridade': 1},
#  'cereais integrais': {'ID': 'D000067348', 'similaridade': 1},
#  'cereal integral': {'ID': 'D000067348', 'similaridade': 1},
#  'graos integrais _i': {'ID': 'D000067348', 'similaridade': 1},
#  'cirurgia endoscópica transanal': {'ID': 'D000067368', 'similaridade': 1},
#  'cirurgia endoscopica transanal _i': {'ID': 'D000067368', 'similaridade': 1},
#  'microcirurgia endoscópica transanal': {'ID': 'D000067369',
#   'similaridade': 1},
#  'microcirurgia endoscopica transanal _i': {'ID': 'D000067369',
#   'similaridade': 1},
#  'lesão por frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesão causada pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesão provocada pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesão pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesão por congelamento': {'ID': 'D000067390', 'similaridade': 1},
#  'lesões causadas pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesões provocadas pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesões pelo frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesões por congelamento': {'ID': 'D000067390', 'similaridade': 1},
#  'lesões por frio': {'ID': 'D000067390', 'similaridade': 1},
#  'lesao por frio _i': {'ID': 'D000067390', 'similaridade': 1},
#  'equipamento de proteção individual': {'ID': 'D000067393', 'similaridade': 1},
#  'equipamento de proteção pessoal': {'ID': 'D000067393', 'similaridade': 1},
#  'equipamentos de proteção individual': {'ID': 'D000067393',
#   'similaridade': 1},
#  'equipamentos de proteção pessoal': {'ID': 'D000067393', 'similaridade': 1},
#  'equipamento de protecao individual _i': {'ID': 'D000067393',
#   'similaridade': 1},
#  'agentes neurotóxicos': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes afetadores dos nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes afetantes dos nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes nervosos': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes neurais': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes que afetam a sinapse': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes que afetam a transmissão sináptica': {'ID': 'D000067397',
#   'similaridade': 1},
#  'agentes que afetam os nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'compostos afetadores da transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'compostos afetantes da transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'compostos neurais': {'ID': 'D000067397', 'similaridade': 1},
#  'compostos neurotóxicos': {'ID': 'D000067397', 'similaridade': 1},
#  'compostos que afetam a transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'substâncias afetadoras dos nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'substâncias afetantes dos nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'substâncias neurais': {'ID': 'D000067397', 'similaridade': 1},
#  'substâncias neurotóxicas': {'ID': 'D000067397', 'similaridade': 1},
#  'substâncias prejudiciais à transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'substâncias que afetam a sinapse': {'ID': 'D000067397', 'similaridade': 1},
#  'substâncias que afetam a transmissão agentes que afetam a transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'substâncias que afetam a transmissão neural': {'ID': 'D000067397',
#   'similaridade': 1},
#  'substâncias que afetam a transmissão sinâptica': {'ID': 'D000067397',
#   'similaridade': 1},
#  'substâncias que afetam os nervos': {'ID': 'D000067397', 'similaridade': 1},
#  'agentes neurotoxicos _i': {'ID': 'D000067397', 'similaridade': 1},
#  'lesões relacionadas à guerra': {'ID': 'D000067398', 'similaridade': 1},
#  'lesoes relacionadas a guerra _i': {'ID': 'D000067398', 'similaridade': 1},
#  'escala de movimento involuntário anormal': {'ID': 'D000067399',
#   'similaridade': 1},
#  'escala de movimentos involuntários anormais': {'ID': 'D000067399',
#   'similaridade': 1},
#  'escala de movimento involuntario anormal _i': {'ID': 'D000067399',
#   'similaridade': 1},
#  'concentração alcoólica no sangue': {'ID': 'D000067401', 'similaridade': 1},
#  'conteúdo alcóolico plasmático': {'ID': 'D000067401', 'similaridade': 1},
#  'conteúdo alcóolico no sangue': {'ID': 'D000067401', 'similaridade': 1},
#  'teor alcoólico no sangue': {'ID': 'D000067401', 'similaridade': 1},
#  'concentracao alcoolica no sangue _i': {'ID': 'D000067401',
#   'similaridade': 1},
#  'transtorno de comunicação social': {'ID': 'D000067404', 'similaridade': 1},
#  'distúrbio social de comunicação': {'ID': 'D000067404', 'similaridade': 1},
#  'distúrbio de comunicação social': {'ID': 'D000067404', 'similaridade': 1},
#  'transtorno social de comunicação': {'ID': 'D000067404', 'similaridade': 1},
#  'transtorno de comunicacao social _i': {'ID': 'D000067404',
#   'similaridade': 1},
#  'serviços jurídicos': {'ID': 'D000067408', 'similaridade': 1},
#  'serviços legais': {'ID': 'D000067408', 'similaridade': 1},
#  'servicos juridicos _i': {'ID': 'D000067408', 'similaridade': 1},
#  'difamação': {'ID': 'D000067448', 'similaridade': 1},
#  'difamacao _i': {'ID': 'D000067448', 'similaridade': 1},
#  'terapia de controle da ira': {'ID': 'D000067449', 'similaridade': 1},
#  'terapia de controle da fúria': {'ID': 'D000067449', 'similaridade': 1},
#  'terapia de controle da ira _i': {'ID': 'D000067449', 'similaridade': 1},
#  'psicologia do esporte': {'ID': 'D000067450', 'similaridade': 1},
#  'psicologia do esporte _i': {'ID': 'D000067450', 'similaridade': 1},
#  'exposição à guerra': {'ID': 'D000067453', 'similaridade': 1},
#  'exposicao a guerra _i': {'ID': 'D000067453', 'similaridade': 1},
#  'transtorno da fluência com início na infância': {'ID': 'D000067454',
#   'similaridade': 1},
#  'distúrbio da fluência com início na infância': {'ID': 'D000067454',
#   'similaridade': 1},
#  'transtorno da fluencia com inicio na infancia _i': {'ID': 'D000067454',
#   'similaridade': 1},
#  'pacientes não comparecentes': {'ID': 'D000067455', 'similaridade': 1},
#  'pacientes ausentes': {'ID': 'D000067455', 'similaridade': 1},
#  'pacientes faltantes': {'ID': 'D000067455', 'similaridade': 1},
#  'pacientes que não comparecem': {'ID': 'D000067455', 'similaridade': 1},
#  'pacientes nao comparecentes _i': {'ID': 'D000067455', 'similaridade': 1},
#  'técnicas de reprogramação celular': {'ID': 'D000067470', 'similaridade': 1},
#  'tecnicas de reprogramacao celular _i': {'ID': 'D000067470',
#   'similaridade': 1},
#  'metacognição': {'ID': 'D000067489', 'similaridade': 1},
#  'metacognicao _i': {'ID': 'D000067489', 'similaridade': 1},
#  'uso excessivo de medicamentos prescritos': {'ID': 'D000067490',
#   'similaridade': 1},
#  'consumo excessivo de medicamentos': {'ID': 'D000067490', 'similaridade': 1},
#  'consumo excessivo de medicamentos prescritos': {'ID': 'D000067490',
#   'similaridade': 1},
#  'consumo excessivo de remédios controlados': {'ID': 'D000067490',
#   'similaridade': 1},
#  'sobrecarga de fármacos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobrecarga de medicamentos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobrecarga do medicamento': {'ID': 'D000067490', 'similaridade': 1},
#  'sobremedicação': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreuso de antibacterianos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreuso de antibióticos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreuso de fármacos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreuso de medicamentos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreuso do medicamento': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreutilização de medicamentos': {'ID': 'D000067490', 'similaridade': 1},
#  'sobreutilização do medicamento': {'ID': 'D000067490', 'similaridade': 1},
#  'uso excessivo de antibacterianos': {'ID': 'D000067490', 'similaridade': 1},
#  'uso excessivo de antibióticos': {'ID': 'D000067490', 'similaridade': 1},
#  'uso excessivo de medicamento': {'ID': 'D000067490', 'similaridade': 1},
#  'uso excessivo de medicamentos': {'ID': 'D000067490', 'similaridade': 1},
#  'uso excessivo de medicamentos controlados': {'ID': 'D000067490',
#   'similaridade': 1},
#  'uso excessivo do medicamento': {'ID': 'D000067490', 'similaridade': 1},
#  'utilização excessiva de medicamentos': {'ID': 'D000067490',
#   'similaridade': 1},
# ...
#   'similaridade': 1},
#  'distúrbio específico de aprendizado': {'ID': 'D000067559',
#   'similaridade': 1},
#  'distúrbio específico de aprendizagem': {'ID': 'D000067559',
#   'similaridade': 1},
#  'distúrbio de aprendizado específico': {'ID': 'D000067559',
#   'similaridade': 1},
#  'distúrbio de aprendizagem específico': {'ID': 'D000067559',
#   'similaridade': 1},
#  'transtorno específico de aprendizado': {'ID': 'D000067559',
#   'similaridade': 1},
#  'transtorno específico de aprendizagem': {'ID': 'D000067559',
#   'similaridade': 1},
#  'transtorno de aprendizado específico': {'ID': 'D000067559',
#   'similaridade': 1},
#  'transtorno de aprendizagem especifico _i': {'ID': 'D000067559',
#   'similaridade': 1},
#  'lista de medicamentos potencialmente inapropriados': {'ID': 'D000067561',
#   'similaridade': 1},
#  'lista de medicamentos potencialmente impróprios': {'ID': 'D000067561',
#   'similaridade': 1},
#  'lista de medicamentos potencialmente perigosos': {'ID': 'D000067561',
#   'similaridade': 1},
#  'medicamentos potencialmente inapropriados': {'ID': 'D000067561',
#   'similaridade': 1},
#  'medicamentos potencialmente perigosos': {'ID': 'D000067561',
#   'similaridade': 1},
#  'lista de medicamentos potencialmente inapropriados _i': {'ID': 'D000067561',
#   'similaridade': 1},
#  'transtornos de início tardio': {'ID': 'D000067562', 'similaridade': 1},
#  'distúrbios de acometimento tardio': {'ID': 'D000067562', 'similaridade': 1},
#  'distúrbios de início tardio': {'ID': 'D000067562', 'similaridade': 1},
#  'transtornos de acometimento tardio': {'ID': 'D000067562', 'similaridade': 1},
#  'transtornos de inicio tardio _i': {'ID': 'D000067562', 'similaridade': 1},
#  'phakopsora pachyrhizi': {'ID': 'D000067563', 'similaridade': 1},
#  'phakopsora pachyrhizi _i': {'ID': 'D000067563', 'similaridade': 1},
#  'fazendeiros': {'ID': 'D000067565', 'similaridade': 1},
#  'agricultor': {'ID': 'D000067565', 'similaridade': 1},
#  'agricultores': {'ID': 'D000067565', 'similaridade': 1},
#  'chacareiro': {'ID': 'D000067565', 'similaridade': 1},
#  'chacareiros': {'ID': 'D000067565', 'similaridade': 1},
#  'fazendeiro': {'ID': 'D000067565', 'similaridade': 1},
#  'granjeiro': {'ID': 'D000067565', 'similaridade': 1},
#  'granjeiros': {'ID': 'D000067565', 'similaridade': 1},
#  'sitiante': {'ID': 'D000067565', 'similaridade': 1},
#  'sitiantes': {'ID': 'D000067565', 'similaridade': 1},
#  'rancheiros': {'ID': 'D000067565', 'similaridade': 1},
#  'fazendeiros _i': {'ID': 'D000067565', 'similaridade': 1},
#  'caminhoneiro _i': {'ID': 'D000067565', 'similaridade': 0.9461120963096619},
#  'tecnologia culturalmente apropriada': {'ID': 'D000067568',
#   'similaridade': 1},
#  'tecnologia apropriada': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia intermediária': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia de custo intermediário': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia leve': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologias leves': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia alternativa': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia básica': {'ID': 'D000067568', 'similaridade': 1},
#  'tecnologia culturalmente apropriada _i': {'ID': 'D000067568',
#   'similaridade': 1},
#  'aprendizado social': {'ID': 'D000067570', 'similaridade': 1},
#  'aprendizagem social': {'ID': 'D000067570', 'similaridade': 1},
#  'aprendizado social _i': {'ID': 'D000067570', 'similaridade': 1},
#  'declarações financeiras': {'ID': 'D000067571', 'similaridade': 1},
#  'declaracoes financeiras _i': {'ID': 'D000067571', 'similaridade': 1},
#  'mineradores': {'ID': 'D000067572', 'similaridade': 1},
#  'mineiros': {'ID': 'D000067572', 'similaridade': 1},
#  'minerador': {'ID': 'D000067572', 'similaridade': 1},
#  'mineradores _i': {'ID': 'D000067572', 'similaridade': 1},
#  'cronofarmacocinética': {'ID': 'D000067573', 'similaridade': 1},
#  'cronofarmacocinetica _i': {'ID': 'D000067573', 'similaridade': 1},
#  'demandas administrativas em assistência à saúde': {'ID': 'D000067575',
#   'similaridade': 1},
#  'processos administrativos dos serviços de saúde': {'ID': 'D000067575',
#   'similaridade': 1},
#  'demandas administrativas em assistencia a saude _i': {'ID': 'D000067575',
#   'similaridade': 1},
#  'saúde da criança': {'ID': 'D000067576', 'similaridade': 1},
#  'saúde infantil': {'ID': 'D000067576', 'similaridade': 1},
#  'saúde pediátrica': {'ID': 'D000067576', 'similaridade': 1},
#  'saúde das crianças': {'ID': 'D000067576', 'similaridade': 1},
#  'saude da crianca _i': {'ID': 'D000067576', 'similaridade': 1},
#  'interleucina-33': {'ID': 'D000067596', 'similaridade': 1},
#  'interleucina-33 _i': {'ID': 'D000067596', 'similaridade': 1},
#  'proteína s100a12': {'ID': 'D000067616', 'similaridade': 1},
#  'proteina s100a12 _i': {'ID': 'D000067616', 'similaridade': 1},
#  'telopódios': {'ID': 'D000067617', 'similaridade': 1},
#  'podômeros': {'ID': 'D000067617', 'similaridade': 1},
#  'telopodios _i': {'ID': 'D000067617', 'similaridade': 1},
#  'drosophila simulans': {'ID': 'D000067636', 'similaridade': 1},
#  'drosophila simulans _i': {'ID': 'D000067636', 'similaridade': 1},
#  'otimismo': {'ID': 'D000067656', 'similaridade': 1},
#  'pensamento positivo': {'ID': 'D000067656', 'similaridade': 1},
#  'otimismo _i': {'ID': 'D000067656', 'similaridade': 1},
#  'pessimismo': {'ID': 'D000067657', 'similaridade': 1},
#  'pensamento negativo': {'ID': 'D000067657', 'similaridade': 1},
#  'pessimismo _i': {'ID': 'D000067657', 'similaridade': 1},
#  'ataxina-1': {'ID': 'D000067696', 'similaridade': 1},
#  'proteína sca1': {'ID': 'D000067696', 'similaridade': 1},
#  'ataxina-1 _i': {'ID': 'D000067696', 'similaridade': 1},
#  'saúde do adolescente': {'ID': 'D000067697', 'similaridade': 1},
#  'caderneta de saúde do adolescente': {'ID': 'D000067697', 'similaridade': 1},
#  'saúde integral do adolescente': {'ID': 'D000067697', 'similaridade': 1},
#  'saúde do jovem': {'ID': 'D000067697', 'similaridade': 1},
#  'saúde dos adolescentes': {'ID': 'D000067697', 'similaridade': 1},
#  'saude do adolescente _i': {'ID': 'D000067697', 'similaridade': 1},
#  'ataxina-2': {'ID': 'D000067698', 'similaridade': 1},
#  'proteína sca2': {'ID': 'D000067698', 'similaridade': 1},
#  'ataxina-2 _i': {'ID': 'D000067698', 'similaridade': 1},
#  'ataxina-3': {'ID': 'D000067699', 'similaridade': 1},
#  'proteína sca3': {'ID': 'D000067699', 'similaridade': 1},
#  'ataxina-3 _i': {'ID': 'D000067699', 'similaridade': 1},
#  'testes imediatos': {'ID': 'D000067716', 'similaridade': 1},
#  'análises clínicas ambulatoriais': {'ID': 'D000067716', 'similaridade': 1},
#  'análises clínicas no ambulatório': {'ID': 'D000067716', 'similaridade': 1},
#  'análises diagnósticas no consultório': {'ID': 'D000067716',
#   'similaridade': 1},
#  'análises do paciente no consultório': {'ID': 'D000067716',
#   'similaridade': 1},
#  'diagnóstico no local de atendimento': {'ID': 'D000067716',
#   'similaridade': 1},
#  'diagnósticos ambulatoriais': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnósticos no ambulatório': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnósticos no local de atendimento': {'ID': 'D000067716',
#   'similaridade': 1},
#  'exames imediatos': {'ID': 'D000067716', 'similaridade': 1},
#  'teste point-of-care': {'ID': 'D000067716', 'similaridade': 1},
#  'teste no consultório': {'ID': 'D000067716', 'similaridade': 1},
#  'teste no local de atendimento': {'ID': 'D000067716', 'similaridade': 1},
#  'testes diagnósticos no consultório': {'ID': 'D000067716', 'similaridade': 1},
#  'testes no consultório': {'ID': 'D000067716', 'similaridade': 1},
#  'testes no local da intervenção': {'ID': 'D000067716', 'similaridade': 1},
#  'testes no local de atendimento': {'ID': 'D000067716', 'similaridade': 1},
#  'testes à beira do leito': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnóstico junto ao leito': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnóstico à beira do leito': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnósticos junto ao leito': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnósticos de cabeceira': {'ID': 'D000067716', 'similaridade': 1},
#  'diagnósticos à beira do leito': {'ID': 'D000067716', 'similaridade': 1},
#  'exames de cabeceira': {'ID': 'D000067716', 'similaridade': 1},
#  'teste junto ao leito': {'ID': 'D000067716', 'similaridade': 1},
#  'teste à beira do leito': {'ID': 'D000067716', 'similaridade': 1},
#  'testes junto ao leito': {'ID': 'D000067716', 'similaridade': 1},
#  'testes de cabeceira': {'ID': 'D000067716', 'similaridade': 1},
#  'testes imediatos _i': {'ID': 'D000067716', 'similaridade': 1},
#  'ataxina-7': {'ID': 'D000067719', 'similaridade': 1},
#  'proteína sca7': {'ID': 'D000067719', 'similaridade': 1},
#  'ataxina-7 _i': {'ID': 'D000067719', 'similaridade': 1},
#  'ataxina-10': {'ID': 'D000067736', 'similaridade': 1},
#  'proteína sca10': {'ID': 'D000067736', 'similaridade': 1},
#  'ataxina-10 _i': {'ID': 'D000067736', 'similaridade': 1},
#  'receptores de peptídeos semelhantes ao glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptor de peptídeo semelhante a glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptor de peptídeo semelhante ao glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptores de peptídeo semelhante a glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptores de peptídeo semelhante ao glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptores de peptídeos semelhantes a glucagon': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptores de peptideos semelhantes ao glucagon _i': {'ID': 'D000067756',
#   'similaridade': 1},
#  'receptor do peptídeo semelhante ao glucagon 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de glp-1': {'ID': 'D000067757', 'similaridade': 1},
#  'receptor de peptídeo glucacon-like 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de peptídeo glucagon-símile 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de peptídeo glucagon-símile tipo 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de peptídeo semelhante a glucagon 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de peptídeo semelhante ao glucagon 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor de peptídeo-1 semelhante ao glucagon': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor do glp-1': {'ID': 'D000067757', 'similaridade': 1},
#  'receptor do peptídeo glucacon-like 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor do peptídeo glucagon-símile tipo 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor do peptídeo semelhante a glucagon 1': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor do peptideo semelhante ao glucagon 1 _i': {'ID': 'D000067757',
#   'similaridade': 1},
#  'receptor do peptídeo semelhante ao glucagon 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor de glp-2': {'ID': 'D000067758', 'similaridade': 1},
#  'receptor de peptídeo glucacon-like 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor de peptídeo glucagon-símile 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor de peptídeo glucagon-símile tipo 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor de peptídeo semelhante ao glucagon 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor de peptídeo-2 semelhante ao glucagon': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor do peptídeo glucacon-like 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor do peptídeo glucagon-símile 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor do peptídeo glucagon-símile tipo 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor do peptídeo semelhante a glucagon 2': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor do peptideo semelhante ao glucagon 2 _i': {'ID': 'D000067758',
#   'similaridade': 1},
#  'receptor para produtos finais de glicação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'proteína ager': {'ID': 'D000067759', 'similaridade': 1},
#  'receptor age': {'ID': 'D000067759', 'similaridade': 1},
#  'receptor específico para produtos finais de glicação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'receptor específico para produtos finais de glicosilação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'receptor rage para produtos finais de glicação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'receptor para anfoterina': {'ID': 'D000067759', 'similaridade': 1},
#  'receptores para produto final de glicação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'receptores para produtos finais de glicosilação avançada': {'ID': 'D000067759',
#   'similaridade': 1},
#  'receptor para produtos finais de glicacao avancada _i': {'ID': 'D000067759',
#   'similaridade': 1},
#  'proteínas com motivo de reconhecimento de rna': {'ID': 'D000067776',
#   'similaridade': 1},
#  'proteínas rrm': {'ID': 'D000067776', 'similaridade': 1},
#  'proteínas com domínio de ligação a rna': {'ID': 'D000067776',
#   'similaridade': 1},
#  'proteínas com domínios de ribonucleoproteínas': {'ID': 'D000067776',
#   'similaridade': 1},
#  'proteínas com motivos de reconhecimento de rna': {'ID': 'D000067776',
#   'similaridade': 1},
#  'proteínas com rrm': {'ID': 'D000067776', 'similaridade': 1},
#  'proteinas com motivo de reconhecimento de rna _i': {'ID': 'D000067776',
#   'similaridade': 1},
#  'proteína semelhante a elav 2': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína 2 elav-like': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína 2 semelhante a elav 2': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína 2 similar a elav': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína elav-like 2': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína similar a elav 2': {'ID': 'D000067777', 'similaridade': 1},
#  'proteina semelhante a elav 2 _i': {'ID': 'D000067777', 'similaridade': 1},
#  'proteína semelhante a elav 3': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína 3 elav-like': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína 3 semelhante a elav': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína 3 similar a elav': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína elav-like 3': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína similar a elav 3': {'ID': 'D000067778', 'similaridade': 1},
#  'proteina semelhante a elav 3 _i': {'ID': 'D000067778', 'similaridade': 1},
#  'proteína semelhante a elav 4': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína 4 elav-like': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína 4 semelhante a elav': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína 4 similar a elav': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína elav-like 4': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína similar a elav 4': {'ID': 'D000067779', 'similaridade': 1},
#  'proteina semelhante a elav 4 _i': {'ID': 'D000067779', 'similaridade': 1},
#  'proteína semelhante a elav 1': {'ID': 'D000067780', 'similaridade': 1},
#  'proteína 1 elav-like': {'ID': 'D000067780', 'similaridade': 1},
#  'proteína 1 semelhante a elav': {'ID': 'D000067780', 'similaridade': 1},
#  'proteína 1 similar a elav': {'ID': 'D000067780', 'similaridade': 1},
#  'proteína elav-like 1': {'ID': 'D000067780', 'similaridade': 1},
#  'proteína similar a elav 1': {'ID': 'D000067780', 'similaridade': 1},
#  'proteina semelhante a elav 1 _i': {'ID': 'D000067780', 'similaridade': 1},
#  'soro do leite': {'ID': 'D000067796', 'similaridade': 1},
#  'soro lácteo': {'ID': 'D000067796', 'similaridade': 1},
#  'soro de leite': {'ID': 'D000067796', 'similaridade': 1},
#  'soro do leite _i': {'ID': 'D000067796', 'similaridade': 1},
#  'proteínas do soro do leite': {'ID': 'D000067816', 'similaridade': 1},
#  'proteinas do soro do leite _i': {'ID': 'D000067816', 'similaridade': 1},
#  'transtorno de acumulação': {'ID': 'D000067836', 'similaridade': 1},
#  'transtorno da acumulação': {'ID': 'D000067836', 'similaridade': 1},
#  'transtorno de colecionismo': {'ID': 'D000067836', 'similaridade': 1},
#  'colecionismo obsessivo': {'ID': 'D000067836', 'similaridade': 1},
#  'transtorno de acumulacao _i': {'ID': 'D000067836', 'similaridade': 1},
#  'inibidores de poli(adp-ribose) polimerases': {'ID': 'D000067856',
#   'similaridade': 1},
#  'inibidores de poli _i': {'ID': 'D000067856', 'similaridade': 1},
#  ...}

# %%
import gzip, pickle


with gzip.open('dictMesh_.dict.gz', 'rb') as fp:
    dictMesh = pickle.load(fp)
    fp.close()
    
print(dictMesh['D000005'])
# Out:
# {'ID': 'D000005', 'name': 'abdome[abdomen]', 'scope': 'região do corpo que se localiza entre o tórax e a pelve.', 'terms': ['abdômen', 'abdome', " <input type='hidden' name='ID' value='D000005'/> "], 'qualifier': 'anatomy & histology'}

# %% [markdown]
# É possível visualizar as informações do Dicionário com o comando abaixo:
#
# - Para acessar o termo desejado é necessário por seu ID.

# %%
Dicionario.indiceReverso['perna _i']

Dicionario.dictMesh['D005850']
# Out:
# {'ID': 'D005850',
#  'name': 'odontologia geriátrica[geriatric dentistry]',
#  'qualifier': 'methods',
#  'scope': 'ramo de odontologia voltado para os problemas odontológicos das pessoas mais idosas.',
#  'terms': ['odontologia geriátrica',
#   'odontogeriatria',
#   " <input type='hidden' name='ID' value='D005850'/> "]}

# %%
originais = 0
expandidos = 0
for termo in Dicionario.indiceReverso:
    if("_i" in termo):
        expandidos +=1
    else:
        originais += 1

print(expandidos, originais)
# Out:
# 40066 80973

# %%
len(Dicionario.dictMesh)
# Out:
# 28939
