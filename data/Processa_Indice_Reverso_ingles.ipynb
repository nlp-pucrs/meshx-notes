# %%
import gzip, pickle
import pandas as pd


with gzip.open('dictMesh.dict_eng.gz','rb') as fp:
    dictMesh = pickle.load(fp)
    fp.close()

# %% [markdown]
# ### Monta Dicionario

# %%
prescription = pd.read_csv('./excel_evol.csv.gz', compression='gzip', nrows=50000)

indiceReverso = {}

for dui in list(dictMesh):
    d = dictMesh[str(dui)]
    for t in d['terms']:
        indiceReverso[t] = {
            'ID': d['ID']
        }

# %%
indiceReverso
# Out:
# {'Calcimycin': {'ID': 'D000001'},
#  'A23187, Antibiotic': {'ID': 'D000001'},
#  'Calcimicina': {'ID': 'D000001'},
#  'A23187': {'ID': 'D000001'},
#  'A-23187': {'ID': 'D000001'},
#  'A 23187': {'ID': 'D000001'},
#  'Antibiotic A23187': {'ID': 'D000001'},
#  'Abate': {'ID': 'D000002'},
#  'Temefós': {'ID': 'D000002'},
#  'Temephos': {'ID': 'D000002'},
#  'Temefos': {'ID': 'D000002'},
#  'Difos': {'ID': 'D000002'},
#  'Slaughterhouses': {'ID': 'D000003'},
#  'Matadouro': {'ID': 'D000003'},
#  'Slaughter House': {'ID': 'D000003'},
#  'Abatedouros': {'ID': 'D000003'},
#  'Slaughterhouse': {'ID': 'D000003'},
#  'Abattoir': {'ID': 'D000003'},
#  'House, Slaughter': {'ID': 'D000003'},
#  'Abattoirs': {'ID': 'D000003'},
#  'Matadouros': {'ID': 'D000003'},
#  'Houses, Slaughter': {'ID': 'D000003'},
#  'Slaughter Houses': {'ID': 'D000003'},
#  'Acronyms as Topic': {'ID': 'D000004'},
#  'Acrônimos como Assunto': {'ID': 'D000004'},
#  'Abbreviations as Topic': {'ID': 'D000004'},
# ...

# %% [markdown]
# ### Salva Dicionario

# %%
import gzip, pickle

with gzip.open('indiceReversoEN.dict.gz','wb') as fp:
    pickle.dump(indiceReverso,fp)
    fp.close()

# %% [markdown]
# ### Carrega Dicionario

# %%
import gzip, pickle

with gzip.open('indiceReversoEN.dictg.gz','rb') as fp:
    indiceReverso = pickle.load(fp)
    fp.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-db51dfe6e4ed> in <module>()
#       1 import gzip, pickle
#       2
# ----> 3 with gzip.open('indiceReversoEN.dictg.gz','rb') as fp:
#       4     indiceReverso = pickle.load(fp)
#       5     fp.close()
#
# /usr/lib/python3.6/gzip.py in open(filename, mode, compresslevel, encoding, errors, newline)
#      51     gz_mode = mode.replace("t", "")
#      52     if isinstance(filename, (str, bytes, os.PathLike)):
# ---> 53         binary_file = GzipFile(filename, gz_mode, compresslevel)
#      54     elif hasattr(filename, "read") or hasattr(filename, "write"):
#      55         binary_file = GzipFile(None, gz_mode, compresslevel, filename)
#
# /usr/lib/python3.6/gzip.py in __init__(self, filename, mode, compresslevel, fileobj, mtime)
#     161             mode += 'b'
#     162         if fileobj is None:
# ...

# %%
    
ID = indiceReverso['Calcimycin']['ID']
ID

dictMesh[ID]['qualifier']
